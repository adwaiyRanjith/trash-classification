# %%
import os, shutil
from google.colab import drive
drive.mount('/content/drive')

os.chdir('/content/trash-classification')
# !git pull

shutil.copy("/content/drive/MyDrive/best_model.pth", "checkpoints/best_model.pth")

# %%
# !python src/evaluate.py
